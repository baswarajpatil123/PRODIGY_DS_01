# %% [markdown]
# # PRODIGY INFOTECH

# %% [markdown]
# # TASK DONE BY : BASWARAJ PATIL

# %% [markdown]
# # PROBLEM STATEMENT

# %% [raw]
# # Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
# importing library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('world2.csv')

# %%
print(df)
# Out:
#                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54608.0      55811.0      56682.0      57475.0
# ...

# %%
df.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
# shape check
df.shape
# Out:
# (266, 67)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
df.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172707e+08  1.188803e+08  1.210506e+08  1.237328e+08  1.264374e+08
# std    3.695437e+08  3.740896e+08  3.808059e+08  3.895038e+08  3.982438e+08
# min    2.646000e+03  2.888000e+03  3.171000e+03  3.481000e+03  3.811000e+03
# 25%    5.132212e+05  5.231345e+05  5.337595e+05  5.449288e+05  5.566630e+05
# 50%    3.757486e+06  3.887144e+06  4.023896e+06  4.139356e+06  4.224612e+06
# 75%    2.670606e+07  2.748694e+07  2.830289e+07  2.914708e+07  3.001684e+07
# max    3.031474e+09  3.072422e+09  3.126850e+09  3.193429e+09  3.260442e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.291808e+08  1.320399e+08  1.348975e+08  1.378354e+08  1.408784e+08
# ...

# %%
df.isna().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 1960              2
#                  ..
# 2018              1
# 2019              1
# 2020              1
# 2021              1
# 2022              1
# Length: 67, dtype: int64

# %%
# Drop unuseful columns
df.drop(columns=['Country Code','Indicator Name'],inplace=True)

# %%
df.sample()
# Out:
#            Country Name Indicator Code      1960      1961      1962  \
# 8  United Arab Emirates    SP.POP.TOTL  133426.0  140984.0  148877.0
#
#        1963      1964      1965      1966      1967  ...       2013  \
# 8  157006.0  165305.0  173797.0  182509.0  191404.0  ...  8751847.0
#
#         2014       2015       2016       2017       2018       2019  \
# 8  8835951.0  8916899.0  8994263.0  9068296.0  9140169.0  9211657.0
#
#         2020       2021       2022
# 8  9287289.0  9365145.0  9441129.0
#
# [1 rows x 65 columns]

# %%
# filter data for total population
total_population_df=df[df['Indicator Code']=='SP.POP.TOTL']
total_population_df
# Out:
#                     Country Name Indicator Code         1960         1961  \
# 0                          Aruba    SP.POP.TOTL      54608.0      55811.0
# 1    Africa Eastern and Southern    SP.POP.TOTL  130692579.0  134169237.0
# 2                    Afghanistan    SP.POP.TOTL    8622466.0    8790140.0
# 3     Africa Western and Central    SP.POP.TOTL   97256290.0   99314028.0
# 4                         Angola    SP.POP.TOTL    5357195.0    5441333.0
# ..                           ...            ...          ...          ...
# 261                       Kosovo    SP.POP.TOTL     947000.0     966000.0
# 262                  Yemen, Rep.    SP.POP.TOTL    5542459.0    5646668.0
# 263                 South Africa    SP.POP.TOTL   16520441.0   16989464.0
# 264                       Zambia    SP.POP.TOTL    3119430.0    3219451.0
# 265                     Zimbabwe    SP.POP.TOTL    3806310.0    3925952.0
#
#             1962         1963         1964         1965         1966  \
# ...

# %%
# sort data based on total population for 2022
total_population_sort = total_population_df.sort_values(by='2022',ascending=False)
total_population_sort
# Out:
#                Country Name Indicator Code          1960          1961  \
# 259                   World    SP.POP.TOTL  3.031474e+09  3.072422e+09
# 103        IDA & IBRD total    SP.POP.TOTL  2.297972e+09  2.329504e+09
# 140     Low & middle income    SP.POP.TOTL  2.243179e+09  2.274050e+09
# 156           Middle income    SP.POP.TOTL  2.107416e+09  2.135116e+09
# 102               IBRD only    SP.POP.TOTL  1.904347e+09  1.926043e+09
# ..                      ...            ...           ...           ...
# 255  British Virgin Islands    SP.POP.TOTL  7.850000e+03  7.885000e+03
# 188                   Palau    SP.POP.TOTL  9.446000e+03  9.639000e+03
# 179                   Nauru    SP.POP.TOTL  4.582000e+03  4.753000e+03
# 245                  Tuvalu    SP.POP.TOTL  5.404000e+03  5.436000e+03
# 110          Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# ...

# %% [markdown]
# # TOP 15 COUNTRIES WITH HIGHEST POPULATION FOR 2022

# %%
# get top 15 countries with the highest population for 2022
top_fifteen_countries = total_population_sort.head(15)
print("Top fifteen Countries Of Total Population:-")
print(top_fifteen_countries)
# Out:
# Top fifteen Countries Of Total Population:-
#                                     Country Name Indicator Code          1960  \
# 259                                        World    SP.POP.TOTL  3.031474e+09
# 103                             IDA & IBRD total    SP.POP.TOTL  2.297972e+09
# 140                          Low & middle income    SP.POP.TOTL  2.243179e+09
# 156                                Middle income    SP.POP.TOTL  2.107416e+09
# 102                                    IBRD only    SP.POP.TOTL  1.904347e+09
# 62                    Early-demographic dividend    SP.POP.TOTL  9.794615e+08
# 139                          Lower middle income    SP.POP.TOTL  9.058328e+08
# 249                          Upper middle income    SP.POP.TOTL  1.201583e+09
# 63                           East Asia & Pacific    SP.POP.TOTL  1.043334e+09
# 142                    Late-demographic dividend    SP.POP.TOTL  1.095549e+09
# ...

# %%
# Data visualization
def add_value_labels(ax,spacing=15):
    for rect in ax.patches:
        x=rect.get_x()+rect.get_width()/2
        y=rect.get_height()-3
        
        va='bottom' if y>=0 else 'top'
        label= '()'.format(y) 
        y_shift = spacing * (1 if y >= 0 else -1)
        ax.annotate(label,(x,y),xytext=(0,y_shift),textcoords="offset points",ha='center',va=va)

# %% [markdown]
# # Top ten countries of total population in year 2022 and 2000

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_countries,palette="Blues")
plt.title("Top Ten countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_countries,palette="Greens")
plt.title("Top Ten countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Top ten countries of total population in year 1999 and 1989

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_countries,palette="Reds")
plt.title("Top Ten countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_countries,palette="Oranges")
plt.title("Top Ten countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Top ten counteirs of total population in year 1960 and 2022

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_countries,palette="Blues")
plt.title("Top Ten countries Of Total Population (1960)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_countries,palette="Greens")
plt.title("Top Ten countries Of Total Population in 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Bottom 10 countries with the highest population

# %%
# sort data based on total population for 2022
total_population_sort_bt = total_population_df.sort_values(by='2022',ascending=True)
total_population_sort_bt
# Out:
#                  Country Name Indicator Code          1960          1961  \
# 245                    Tuvalu    SP.POP.TOTL  5.404000e+03  5.436000e+03
# 179                     Nauru    SP.POP.TOTL  4.582000e+03  4.753000e+03
# 188                     Palau    SP.POP.TOTL  9.446000e+03  9.639000e+03
# 255    British Virgin Islands    SP.POP.TOTL  7.850000e+03  7.885000e+03
# 147  St. Martin (French part)    SP.POP.TOTL  4.135000e+03  4.258000e+03
# ..                        ...            ...           ...           ...
# 156             Middle income    SP.POP.TOTL  2.107416e+09  2.135116e+09
# 140       Low & middle income    SP.POP.TOTL  2.243179e+09  2.274050e+09
# 103          IDA & IBRD total    SP.POP.TOTL  2.297972e+09  2.329504e+09
# 259                     World    SP.POP.TOTL  3.031474e+09  3.072422e+09
# 110            Not classified    SP.POP.TOTL           NaN           NaN
#
#              1962          1963          1964          1965          1966  \
# ...

# %%
top_ten_bt_countries = total_population_sort_bt.head(10)
print("Top Ten Bottom Counteies Of Total Population:-")
print(top_ten_bt_countries)
# Out:
# Top Ten Bottom Counteies Of Total Population:-
#                  Country Name Indicator Code     1960     1961     1962  \
# 245                    Tuvalu    SP.POP.TOTL   5404.0   5436.0   5471.0
# 179                     Nauru    SP.POP.TOTL   4582.0   4753.0   4950.0
# 188                     Palau    SP.POP.TOTL   9446.0   9639.0   9851.0
# 255    British Virgin Islands    SP.POP.TOTL   7850.0   7885.0   7902.0
# 147  St. Martin (French part)    SP.POP.TOTL   4135.0   4258.0   4388.0
# 84                  Gibraltar    SP.POP.TOTL  21822.0  21907.0  22249.0
# 212                San Marino    SP.POP.TOTL  15556.0  15895.0  16242.0
# 149                    Monaco    SP.POP.TOTL  21797.0  21907.0  22106.0
# 137             Liechtenstein    SP.POP.TOTL  16472.0  16834.0  17221.0
# 155          Marshall Islands    SP.POP.TOTL  15374.0  15867.0  16387.0
#
#         1963     1964     1965     1966     1967  ...     2013     2014  \
# ...

# %% [markdown]
# # Bottom ten counteirs of total population in year 2022 and 2000

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="Reds")
plt.title("Top Ten Bottom countries Of Total Population (2022)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2000',y="Country Name",data=top_ten_bt_countries,palette="Oranges")
plt.title("Top Ten Bottom countries Of Total Population in 2000")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Bottom ten counteirs of total population in year 1999 and 1989

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1999',y="Country Name",data=top_ten_bt_countries,palette="Greens")
plt.title("Top Ten Bottom countries Of Total Population (1999)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='1989',y="Country Name",data=top_ten_bt_countries,palette="Blues")
plt.title("Top Ten Bottom countries Of Total Population in 1989")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %% [markdown]
# # Bottom ten counteirs of total population in year 1960 and 2022

# %%
# creat a bar plot
plt.figure(figsize=(20,13))
plt.rcParams['axes.facecolor']=="black"

plt.subplot(2,2,1)
plot=sns.barplot(x='1960',y="Country Name",data=top_ten_bt_countries,palette="Reds")
plt.title("Top Ten Bottom countries Of Total Population (1960)")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.subplot(2,2,2)
plot=sns.barplot(x='2022',y="Country Name",data=top_ten_bt_countries,palette="Oranges")
plt.title("Top Ten Bottom countries Of Total Population in 2022")
plt.xlabel("Total population")
plt.ylabel("country")
add_value_labels(plot)

plt.tight_layout()

# %%
df.sample(10)
# Out:
#                                      Country Name Indicator Code         1960  \
# 145                                        Latvia    SP.POP.TOTL    2120979.0
# 229                                          Chad    SP.POP.TOTL    3028688.0
# 112                            Iran, Islamic Rep.    SP.POP.TOTL   21388806.0
# 66                                        Ecuador    SP.POP.TOTL    4618158.0
# 231  Europe & Central Asia (IDA & IBRD countries)    SP.POP.TOTL  307910628.0
# 240                       South Asia (IDA & IBRD)    SP.POP.TOTL  571192428.0
# 73                                 European Union    SP.POP.TOTL  356947129.0
# 226                                    Seychelles    SP.POP.TOTL      41700.0
# 242                           Trinidad and Tobago    SP.POP.TOTL     847063.0
# 258                                       Vanuatu    SP.POP.TOTL      64608.0
#
#             1961         1962         1963         1964         1965  \
# ...

# %%
population=df["Country Name"]
year=df["1960"]
colors=["#1f77b4","#ff7f)3","#2ca02c","#d62728","8c564b"]
plt.pie(year,labels=population,colors=colors,autopct='%1.1f%%',shadow=True,startangle=140)
plt.show

# %% [markdown]
# # Thankyou
